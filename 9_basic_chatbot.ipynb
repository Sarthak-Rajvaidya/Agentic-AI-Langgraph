# %% [markdown]
# Here we will build a basic chatbot uisng Langgaph where we will message and then we will store its message history as well

# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict,Literal,Annotated
from langchain_core.messages import BaseMessage,HumanMessage
from langchain_groq import ChatGroq
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from langgraph.graph import StateGraph,START,END
# ----> 2 from typing import TypedDict,Literal,Annonated
#       3 from langchain_core.messages import BaseMessage,HumanMessage
#       4 from langchain_groq import ChatGroq
#
# ImportError: cannot import name 'Annonated' from 'typing' (C:\Python312\Lib\typing.py)
