# %% [markdown]
# Here to undertand conditional workflow we will do a case study that is for quadratic equation ok :-

# %% [markdown]
# In quadratic we have discrminant  d=b^2-4ac
#
# of if d>0 - two real roots
#    else if d = 0 same real roots
#    else (d<0) no real roots

# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict,Literal

# %%
#making of statre

class QuadState(TypedDict):
    a:int
    b:int
    c:int
    
    equation:str
    discriminant:float
    result:str

# %%
def show_equation(state:QuadState):
    equation = f'{stste["a"]}x2{state["b"]}x{state["c"]}'
    
    return {'equation':equation}

def calculate_discriminant(state:QuadState):
    state["b"]**2-(4*state["a"]*state["c"])
    
    return {'discriminant':discriminant}

# %%
graph = StateGraph(QuadState)
graph.add_node('show_equation',show_equation)
graph.add_node('calculate_discriminant',calculate_discriminant)

graph.add_edge(START,'show_equation')
graph.add_edge('show_equation','calculate_discriminant')
graph.add_edge('calculate_discriminant',END)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 graph = StateGraph(QuadState)
#       2 graph.add_node('show_equation',show_equation)
# ----> 3 graph.add_node('calculate_discriminant',calculate_discrminant)
#       4
#       5 graph.add_edge(START,'show_equation')
#       6 graph.add_edge('show_equation','calculate_discriminant')
#
# NameError: name 'calculate_discrminant' is not defined
