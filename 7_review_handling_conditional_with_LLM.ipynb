# %% [markdown]
# In this workflow we are doing somtehing differnet we are uisng review handling test case ..
#
# Like see what wwe are doing we will star first then we will find sentiments if its positve acc to parameters well and good we are done if not if ot comes negative response we will do run diagnosois that why is it negative ok so this the the plan

# %%
#import libarries

# %%
from langgraph.graph import StateGraph,START,END
from langchain_groq import ChatGroq
from typing import TypedDict,Literal
from dotenv import load_dotenv
from pydantic import BaseModel,Field

# %%
load_dotenv()

model = ChatGroq(
    model="openai/gpt-oss-20b",
    temperature=0
)

# %%
load_dotenv()
# Out:
# True

# %%
#schema for strctured output
class SentimentSchema(BaseModel):
    sentiment:Literal["positive","negative"] = Field(description="Sentiment of the review")

# %%
class DiagnosisSchema(BaseModel):
    issue_type: Literal["UX", "Performance", "Bug", "Support", "Other"] = Field(description='The category of issue mentioned in the review')
    tone: Literal["angry", "frustrated", "disappointed", "calm"] = Field(description='The emotional tone expressed by the user')
    urgency: Literal["low", "medium", "high"] = Field(description='How urgent or critical the issue appears to be')

# %%
structured_model = model.with_structured_output(SentimentSchema)
structured_model2 = model.with_structured_output(DiagnosisSchema)

# %%
prompt = "What is the sentiment of the following review - The software is too bad"

result = structured_model.invoke(prompt)

print(result.sentiment)
# Out:
# negative

# %%
class ReviewState(TypedDict):
    review:str
    sentiment:Literal["positive","negative"]
    diagnosis:dict
    response:str

# %%
def find_sentiment(state:ReviewState):
    prompt = f'For the following review find out the sentiment \n{state["review"]}'
    sentiment = structured_model.invoke(prompt).sentiment
    return {'sentiment':sentiment}

def check_sentiment(state:ReviewState)->Literal["positive_response","run_diagnosis"]:
    
    if state['sentiment'] == 'positive':
        return 'positive_response'
    else:
        return 'run_diagnosis'

def positive_response(state: ReviewState):

    prompt = f"""Write a warm thank-you message in response to this review:
    \n\n\"{state['review']}\"\n
Also, kindly ask the user to leave feedback on our website."""
    
    response = model.invoke(prompt).content

    return {'response': response}


def run_diagnosis(state: ReviewState):

    prompt = f"""Diagnose this negative review:\n\n{state['review']}\n"
    "Return issue_type, tone, and urgency.
"""
    response = structured_model2.invoke(prompt)

    return {'diagnosis': response.model_dump()}
#model.dump - to convert into disctionary 
# Json - dict and store in diagnosis


def negative_response(state: ReviewState):

    diagnosis = state['diagnosis']

    prompt = f"""You are a support assistant.
The user had a '{diagnosis['issue_type']}' issue, sounded '{diagnosis['tone']}', and marked urgency as '{diagnosis['urgency']}'.
Write an empathetic, helpful resolution message.
"""
    response = model.invoke(prompt).content

    return {'response': response}

# %%
graph = StateGraph(ReviewState)

graph.add_node('find_sentiment', find_sentiment)
graph.add_node('positive_response', positive_response)
graph.add_node('run_diagnosis', run_diagnosis)
graph.add_node('negative_response', negative_response)

graph.add_edge(START, 'find_sentiment')

graph.add_conditional_edges('find_sentiment', check_sentiment)

graph.add_edge('positive_response', END)

graph.add_edge('run_diagnosis', 'negative_response')
graph.add_edge('negative_response', END)

workflow = graph.compile()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 14
#      10 graph.add_edge('positive_response',END)
#      11
#      12 graph.add_edge('run_diagnosis','negative_diagnosis')
#      13 graph.add_edge('negative_diagnosis',END)
# ---> 14 workflow = graph.compile()
#
# File ~\OneDrive\Desktop\Langgarph-tutorials\myenv\Lib\site-packages\langgraph\graph\state.py:1261, in StateGraph.compile(self, checkpointer, cache, store, interrupt_before, interrupt_after, debug, name, transformers)
#    1258 interrupt_after = interrupt_after or []
#    1260 # validate the graph
# -> 1261 self.validate(
#    1262     interrupt=(
#    1263         (interrupt_before if interrupt_before != "*" else []) + interrupt_after
#    1264         if interrupt_after != "*"
#    1265         else []
#    1266     )
#    1267 )
#    1269 # prepare output channels
#    1270 output_channels = (
#    1271     "__root__"
#    1272     if len(self.schemas[self.output_schema]) == 1
#    (...)   1278     ]
#    1279 )
#
# File ~\OneDrive\Desktop\Langgarph-tutorials\myenv\Lib\site-packages\langgraph\graph\state.py:1140, in StateGraph.validate(self, interrupt)
#    1138 for source in all_sources:
#    1139     if source not in self.nodes and source != START:
# -> 1140         raise ValueError(f"Found edge starting at unknown node '{source}'")
#    1142 if START not in all_sources:
#    1143     raise ValueError(
#    1144         "Graph must have an entrypoint: add at least one edge from START to another node"
#    1145     )
#
# ValueError: Found edge starting at unknown node 'negative_diagnosis'

# %%
workflow

# %%
initial_tate={
    'review':'The product was really good '
}

workflow.invoke(initial_tate)
# Out:
# {'review': 'The product was really good ', 'sentiment': 'positive'}
